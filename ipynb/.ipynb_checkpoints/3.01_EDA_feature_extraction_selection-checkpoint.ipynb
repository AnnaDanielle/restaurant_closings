# %%
import os
os.chdir('../')

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import Lasso
from sklearn.externals import joblib
from urllib import urlencode
import matplotlib.pyplot as plt
import lib.yelp_api as yp
import seaborn as sns
import pandas as pd
import numpy as np
import requests
import json
import re

# %matplotlib inline

# %%
yelp_df = pd.read_pickle('data/yelp_data_reviews.pkl')

# %%
yelp_df.head(1)
# Out:
#                               search_name     search_address  \
# 101-asian-kitchen-los-angeles  WOK MASTER  7170 BEVERLY BLVD
#
#                                                       bus_id  \
# 101-asian-kitchen-los-angeles  101-asian-kitchen-los-angeles
#
#                                             name price    cat_1  cat_2 closed  \
# 101-asian-kitchen-los-angeles  101 Asian Kitchen    $$  chinese  sushi  False
#
#                                          address         city  \
# 101-asian-kitchen-los-angeles  7170 Beverly Blvd  Los Angeles
#
#                                     ...        author_rating_36  author_37  \
# 101-asian-kitchen-los-angeles       ...                     2.0       None
#
#                                post_date_37  author_rating_37  author_38  \
# 101-asian-kitchen-los-angeles          None               NaN       None
#
#                               post_date_38 author_rating_38  author_39  \
# 101-asian-kitchen-los-angeles         None              NaN       None
#
#                               post_date_39 author_rating_39
# 101-asian-kitchen-los-angeles         None              NaN
#
# [1 rows x 135 columns]

# %%
rest_df = pd.read_pickle('data/la_rest_group_df.pkl')

# %%
rest_df.head(1)
# Out:
#   facility              address         city zip_cd  num_at_address  \
# 0  #1 CAFE  2080 CENTURY PARK E  LOS ANGELES  90067               1
#
#    max_seats  phone  risk_level last_inspect_date  inspect_score   cat  \
# 0         30  +1nan           3        2016-08-18           90.0  None
#
#    closed_est  year
# 0           0  2016

# %%
cmplt_rest_df = pd.merge(rest_df, yelp_df, left_on=['facility', 'address'], 
                         right_on=['search_name', 'search_address'], how='left')

cmplt_rest_df.head()
# Out:
#                facility            address_x       city_x zip_cd  \
# 0               #1 CAFE  2080 CENTURY PARK E  LOS ANGELES  90067
# 1  #1 CHINESE FAST FOOD   8606 S VERMONT AVE  LOS ANGELES  90044
# 2              #1 DONUT   8509 S FIGUEROA ST  LOS ANGELES  90003
# 3             #1 DONUTS   8509 S FIGUEROA ST  LOS ANGELES  90003
# 4           #2 MOON BBQ    478 N WESTERN AVE  LOS ANGELES  90004
#
#    num_at_address  max_seats         phone  risk_level last_inspect_date  \
# 0               1         30         +1nan           3        2016-08-18
# 1               1         30  +12132358779           3        2016-08-10
# 2               2         30         +1nan           2        2016-05-17
# 3               2         30  +16266957898           2        2016-07-26
# 4               1        150  +13234656707           3        2016-10-12
#
#    inspect_score       ...        author_rating_36  author_37  post_date_37  \
# 0           90.0       ...                     NaN        NaN           NaN
# 1           92.0       ...                     NaN        NaN           NaN
# 2           98.0       ...                     NaN        NaN           NaN
# 3           91.0       ...                     NaN        NaN           NaN
# 4           92.0       ...                     NaN        NaN           NaN
#
#   author_rating_37 author_38 post_date_38 author_rating_38 author_39  \
# 0              NaN       NaN          NaN              NaN       NaN
# 1              NaN       NaN          NaN              NaN       NaN
# 2              NaN       NaN          NaN              NaN       NaN
# 3              NaN       NaN          NaN              NaN       NaN
# 4              NaN       NaN          NaN              NaN       NaN
#
#   post_date_39 author_rating_39
# 0          NaN              NaN
# 1          NaN              NaN
# 2          NaN              NaN
# 3          NaN              NaN
# 4          NaN              NaN
#
# [5 rows x 148 columns]

# %%
post_cols = ['post_date_' + str(i) for i in range(0,40)]

# %%
for col in post_cols:
    cmplt_rest_df[col] = pd.to_datetime(cmplt_rest_df[col], format="%Y-%m-%d")

# %%
cmplt_rest_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9549 entries, 0 to 9548
# Columns: 148 entries, facility to author_rating_39
# dtypes: datetime64[ns](41), float64(45), int64(5), object(57)
# memory usage: 10.9+ MB

# %%
cmplt_rest_df['max_rvw_dt'] = cmplt_rest_df[post_cols].max(axis=1).astype('datetime64[ns]')
cmplt_rest_df['min_rvw_dt'] = cmplt_rest_df[post_cols].min(axis=1).astype('datetime64[ns]')
cmplt_rest_df['est_rst_open'] = cmplt_rest_df['max_rvw_dt'] - cmplt_rest_df['min_rvw_dt']

# %%
auth_cols = ['author_' + str(i) for i in range(0,40)]

# %%
def replc_chars(x):
    try:
        return str(x)
    except:
        return 'auth_rplc'

# %%
for col in auth_cols:
    cmplt_rest_df[col] = cmplt_rest_df[col].apply(replc_chars)

# %%
cmplt_rest_df['name'] = cmplt_rest_df['name'].str.replace(u'ñ', 'n')
cmplt_rest_df['name'] = cmplt_rest_df['name'].str.replace(u'Ü', 'u')
cmplt_rest_df['name'] = cmplt_rest_df['name'].str.replace(u'é', 'e')
cmplt_rest_df['name'] = cmplt_rest_df['name'].str.replace(u'è', 'e')
cmplt_rest_df['name'] = cmplt_rest_df['name'].str.replace(u'ö', 'o')
cmplt_rest_df['name'] = cmplt_rest_df['name'].str.replace(u'à', 'a')
cmplt_rest_df['name'] = cmplt_rest_df['name'].str.replace(u'ä', 'a')
cmplt_rest_df['name'] = cmplt_rest_df['name'].str.replace(u'ō', 'o')
cmplt_rest_df['name'] = cmplt_rest_df['name'].str.replace(u'¢', 'c')
cmplt_rest_df['name'] = cmplt_rest_df['name'].str.replace(u'ó', 'o')
cmplt_rest_df['name'] = cmplt_rest_df['name'].str.replace(u'ú', 'u')
cmplt_rest_df['name'] = cmplt_rest_df['name'].str.replace(u'ü', 'u')
cmplt_rest_df['bus_id'] = cmplt_rest_df['bus_id'].str.replace(u'ü', 'u')
cmplt_rest_df['bus_id'] = cmplt_rest_df['bus_id'].str.replace(u'ñ', 'n')
cmplt_rest_df['bus_id'] = cmplt_rest_df['bus_id'].str.replace(u'Ü', 'u')
cmplt_rest_df['bus_id'] = cmplt_rest_df['bus_id'].str.replace(u'é', 'e')
cmplt_rest_df['bus_id'] = cmplt_rest_df['bus_id'].str.replace(u'è', 'e')
cmplt_rest_df['bus_id'] = cmplt_rest_df['bus_id'].str.replace(u'ö', 'o')
cmplt_rest_df['bus_id'] = cmplt_rest_df['bus_id'].str.replace(u'à', 'a')
cmplt_rest_df['bus_id'] = cmplt_rest_df['bus_id'].str.replace(u'ä', 'a')
cmplt_rest_df['bus_id'] = cmplt_rest_df['bus_id'].str.replace(u'ō', 'o')
cmplt_rest_df['bus_id'] = cmplt_rest_df['bus_id'].str.replace(u'¢', 'c')
cmplt_rest_df['bus_id'] = cmplt_rest_df['bus_id'].str.replace(u'ó', 'o')
cmplt_rest_df['bus_id'] = cmplt_rest_df['bus_id'].str.replace(u'ú', 'u')

# %%
ylp_lacnty_df = cmplt_rest_df[cmplt_rest_df['name'] > 0]

# %%
ylp_lacnty_df.head()
# Out:
#                   facility              address_x       city_x zip_cd  \
# 4              #2 MOON BBQ      478 N WESTERN AVE  LOS ANGELES  90004
# 5              #2 MOON BBQ      478 N WESTERN AVE  LOS ANGELES  90004
# 9                    1 WOK  5565 W MANCHESTER AVE  LOS ANGELES  90045
# 14  10880 WILSHIRE TRIMANA    10880 WILSHIRE BLVD  LOS ANGELES  90024
# 16   1632THAI SILK EXPRESS         1260 S SOTO ST  LOS ANGELES  90023
#
#     num_at_address  max_seats         phone  risk_level last_inspect_date  \
# 4                1        150  +13234656707           3        2016-10-12
# 5                1        150  +13234656707           3        2016-10-12
# 9                2         30  +13105689192           3        2016-12-08
# 14               1         60  +13104703683           3        2016-10-25
# 16               6         30  +13232684695           3        2016-09-23
#
#     inspect_score     ...      author_rating_37   author_38  post_date_38  \
# 4            92.0     ...                   NaN        None           NaT
# 5            92.0     ...                   1.0   Martin E.    2017-01-05
# 9            92.0     ...                   5.0    Reese M.    2013-01-30
# 14           98.0     ...                   NaN        None           NaT
# 16           93.0     ...                   4.0  Mallory S.    2013-09-01
#
#    author_rating_38  author_39 post_date_39 author_rating_39 max_rvw_dt  \
# 4               NaN       None          NaT              NaN 2012-09-17
# 5               1.0  Deedee C.   2016-12-26              5.0 2017-03-01
# 9               3.0     Dan G.   2011-08-16              3.0 2017-01-13
# 14              NaN       None          NaT              NaN 2017-02-08
# 16              4.0     Ana H.   2016-07-07              1.0 2017-03-03
#
#    min_rvw_dt est_rst_open
# 4  2012-09-17       0 days
# 5  2012-04-29    1767 days
# 9  2010-03-21    2490 days
# 14 2009-07-13    2767 days
# 16 2009-12-21    2629 days
#
# [5 rows x 151 columns]

# %%
ylp_lacnty_df = ylp_lacnty_df[['bus_id', 'search_name', 'name', 'search_address',  
                               'address_y', 'max_seats', 'risk_level', 'inspect_score', 
                               'price', 'cat_1', 'cat_2', 'zip_code',
                               'latitude', 'longitude', 'num_reviews', 'avg_rating',
                               'min_rvw_dt', 'max_rvw_dt', 'est_rst_open', 'closed']]

# %%
pd.DataFrame.to_csv(ylp_lacnty_df, 'data/tableau_cmplt_data.csv')

# %%
ylp_lacnty_df.sort_values('num_reviews', ascending=False)
# Out:
#                                                  bus_id  \
# 860                           bottega-louie-los-angeles
# 9028               urth-caffe-downtown-la-los-angeles-2
# 639                                  bestia-los-angeles
# 5225                      masa-of-echo-park-los-angeles
# 436                kang-ho-dong-baekjeong-los-angeles-4
# 6074                          orochon-ramen-los-angeles
# 8945            tsujita-la-artisan-noodle-los-angeles-2
# 2643                emc-seafood-and-raw-bar-los-angeles
# 8654                         the-pie-hole-los-angeles-3
# 6881                           republique-los-angeles-2
# 433                           baco-mercat-los-angeles-2
# 5594                       marugame-monzo-los-angeles-2
# 583                            beer-belly-los-angeles-2
# 7396                       silverlake-ramen-los-angeles
# 7215                hokkaido-ramen-santouka-los-angeles
# 3288  shin-sen-gumi-hakata-ramen-little-tokyo-los-an...
# 8292                            tatsu-ramen-los-angeles
# 8427                       the-boiling-crab-los-angeles
# 3669                                  ink-los-angeles-2
# 308                                     aoc-los-angeles
# 5560                            mohawk-bend-los-angeles
# 8995                   umami-burger-los-feliz-los-feliz
# 8293                          tatsu-ramen-los-angeles-4
# 1081                             cafe-dulce-los-angeles
# 4295                              kyochon-los-angeles-3
# 1634                      churros-calientes-los-angeles
# 1683                                   cleo-los-angeles
# 3242                             guisados-los-angeles-3
# 6900                       faith-and-flower-los-angeles
# 4990                            luna-park-los-angeles-4
# ...                                                 ...
# 1116                      kosher-restaurant-los-angeles
# 5725                     nak-won-restaurant-los-angeles
# 5662                              red-basil-los-angeles
# 7418               singapores-banana-leaf-los-angeles-2
# 2172                             donut-king-los-angeles
# 2632                                  elens-los-angeles
# 2675                          restaurante-8-los-angeles
# 5520                         cucina-rustica-los-angeles
# 5519                         888-wilshire-los-angeles-4
# 84                        fortune-west-cafe-los-angeles
# 8487                        the-coffee-loko-los-angeles
# 5845                  nissi-bakery-and-cafe-los-angeles
# 2412                     mariscos-el-corita-los-angeles
# 1117                            petite-cafe-los-angeles
# 6171           panaderia-salvadorena-bakery-los-angeles
# 2173                           donut-king-los-angeles-5
# 2182                             donut-king-los-angeles
# 430       il-capriccio-wood-fire-pizzeria-los-angeles-2
# 6234                         panda-dumpling-los-angeles
# 6217                            panda-wok-los-angeles-2
# 6166            panaderia-hispano-americana-los-angeles
# 9344       xiomaras-restaurant-and-catering-los-angeles
# 8171                          tacos-tumbras-los-angeles
# 2347               tortas-ahogadas-las-orginales-vernon
# 8238                      taqueria-don-lupe-los-angeles
# 8274                         energy-station-los-angeles
# 4                                dal-dae-po-los-angeles
# 8279                   taste-of-the-islands-los-angeles
# 5777             neris-bakery-and-fast-food-los-angeles
# 3380                   omniherb-momedanbi-los-angeles-4
#
#                         search_name  \
# 860                   BOTTEGA LOUIE
# 9028                     URTH CAFFE
# 639                          BESTIA
# 5225       MASA OF ECHO PARK BAKERY
# 436                       BAEKJEONG
# 6074                  OROCHON RAMEN
# 8945          TSUJITA LA RESTAURANT
# 2643       EMC RESTAURANT GROUP LLC
# 8654                   THE PIE HOLE
# 6881                     REPUBLIQUE
# 433                     BACO MERCAT
# 5594                          MONZO
# 583                      BEER BELLY
# 7396               SILVERLAKE RAMEN
# 7215                  SANUKI SANDOU
# 3288     HAKATA RAMEN SHIN SEN GUMI
# 8292                    TATSU RAMEN
# 8427    THE BOILING CRAB (TAKE OUT)
# 3669                            INK
# 308                             AOC
# 5560                    MOHAWK BEND
# 8995         UMAMI BURGER HOLLYWOOD
# 8293                    TATSU RAMEN
# 1081                     CAFE DULCE
# 4295                KYOCHON CHICKEN
# 1634              CHURROS CALIENTES
# 1683                           CLEO
# 3242                       GUISADOS
# 6900                     RESTAURANT
# 4990                      LUNA PARK
# ...                             ...
# 1116                  CAFE OF PARIS
# 5725                NAKWON CATERING
# 5662                     MUANG PHET
# 7418         SINGAPORES BANANA LEAF
# 2172                     DONUT KING
# 2632  ELENS RESTAURANT MEXICAN FOOD
# 2675            ESTHERS  RESTAURANT
# 5520                           MIRO
# 5519                           MIRO
# 84               88 CHINESE & SUSHI
# 8487                THE COFFEE LOKO
# 5845                   NISSI BAKERY
# 2412                      EL CORITA
# 1117                  CAFE OF PARIS
# 6171          PANADERIA SALVADORENA
# 2173                     DONUT KING
# 2182                    DONUTS KING
# 430                   BACKYARD 4518
# 6234                        PAO JAO
# 6217                      PANDA WOK
# 6166    PANADERIA HISPANO AMERICANA
# 9344            XIOMARAS RESTAURANT
# 8171                  TACOS TUMBRAS
# 2347                      EL ATORON
# 8238              TAQUERIA DON LUPE
# 8274                 TASTE OF CHINA
# 4                       #2 MOON BBQ
# 8279           TASTE OF THE ISLANDS
# 5777        NERISBAKERY & FAST FOOD
# 3380           HERB AND TEA TERAPHY
#
#                                            name  \
# 860                               Bottega Louie
# 9028                   Urth Caffe - Downtown LA
# 639                                      Bestia
# 5225                          Masa of Echo Park
# 436                      Kang Ho-dong Baekjeong
# 6074                              Orochon Ramen
# 8945                  Tsujita LA Artisan Noodle
# 2643                      EMC Seafood & Raw Bar
# 8654                               The Pie Hole
# 6881                                 Republique
# 433                                 Baco Mercat
# 5594                             Marugame Monzo
# 583                                  Beer Belly
# 7396                           Silverlake Ramen
# 7215                    Hokkaido Ramen Santouka
# 3288  Shin-Sen-Gumi Hakata Ramen - Little Tokyo
# 8292                                Tatsu Ramen
# 8427                           The Boiling Crab
# 3669                                        Ink
# 308                                         AOC
# 5560                                Mohawk Bend
# 8995                   Umami Burger - Los Feliz
# 8293                                Tatsu Ramen
# 1081                                 Cafe Dulce
# 4295                                    KyoChon
# 1634                          Churros Calientes
# 1683                                       Cleo
# 3242                                   Guisados
# 6900                             Faith & Flower
# 4990                                  Luna Park
# ...                                         ...
# 1116                          Kosher Restaurant
# 5725                         Nak Won Restaurant
# 5662                                  Red Basil
# 7418                    Singapore's Banana Leaf
# 2172                                 Donut King
# 2632                                     Elen's
# 2675                              Restaurante 8
# 5520                             Cucina Rustica
# 5519                               888 Wilshire
# 84                            Fortune West Cafe
# 8487                            The Coffee Loko
# 5845                        Nissi Bakery & Cafe
# 2412                         Mariscos El Corita
# 1117                                Petite Cafe
# 6171               Panaderia Salvadorena Bakery
# 2173                                 Donut King
# 2182                                 Donut King
# 430             Il Capriccio Wood Fire Pizzeria
# 6234                             Panda Dumpling
# 6217                                  Panda Wok
# 6166                Panaderia Hispano Americana
# 9344           Xiomaras Restaurant and Catering
# 8171                              Tacos Tumbras
# 2347              Tortas Ahogadas Las Orginales
# 8238                          Taqueria don Lupe
# 8274                             Energy Station
# 4                                    Dal Dae Po
# 8279                       Taste of the Islands
# 5777                Neri's Bakery and Fast Food
# 3380                         Omniherb Momedanbi
#
#                         search_address                         address_y  \
# 860                    700 S GRAND AVE                   700 S Grand Ave
# 9028                   451 S NEWITT ST                   451 S Hewitt St
# 639                      2121 E 7TH PL                     2121 E 7th Pl
# 5225                1800 W SUNSET BLVD                1800 W Sunset Blvd
# 436                      3465 W 6TH ST                     3465 W 6th St
# 6074  123 ASTRONAUT ELLISON ONIZUKA ST      123 Astronaut E S Onizuka St
# 8945                2057 SAWTELLE BLVD                2057 Sawtelle Blvd
# 2643                     3500 W 6TH ST                     3500 W 6th St
# 8654                  714 TRACTION AVE                  714 Traction Ave
# 6881                 624 S LA BREA AVE                 624 S La Brea Ave
# 433                      408 S MAIN ST                     408 S Main St
# 5594                      329 E 1ST ST                      329 E 1st St
# 583                  532 S WESTERN AVE                 532 S Western Ave
# 7396                2927 W SUNSET BLVD                2927 W Sunset Blvd
# 7215              3760 S CENTINELA AVE              3760 S Centinela Ave
# 3288                 132 S CENTRAL AVE                 132 S Central Ave
# 8292                2123 SAWTELLE BLVD                2123 Sawtelle Blvd
# 8427                3377 WILSHIRE BLVD                3377 Wilshire Blvd
# 3669                  8360 MELROSE AVE                  8360 Melrose Ave
# 308                      8700 W 3RD ST                     8700 W 3rd St
# 5560                2141 W SUNSET BLVD                2141 W Sunset Blvd
# 8995               4655 HOLLYWOOD BLVD               4655 Hollywood Blvd
# 2173 -118.245934          1.0    5.000000 2011-05-25 2011-05-25        0 days
# 2182 -118.245934          1.0    5.000000 2009-04-11 2009-04-11        0 days
# 430  -118.288025          1.0    1.000000 2014-09-08 2014-09-08        0 days
# 6234 -118.308189          1.0    3.000000 2008-10-19 2008-10-19        0 days
# 6217 -118.327038          1.0    5.000000 2015-05-28 2015-05-28        0 days
# 6166 -118.272011          1.0    5.000000 2015-10-30 2015-10-30        0 days
# 9344 -118.163757          1.0    5.000000 2015-12-02 2015-12-02        0 days
# 8171 -118.265620          1.0    5.000000 2015-11-07 2015-11-07        0 days
# 2347 -118.242889          1.0    1.000000 2011-08-07 2011-08-07        0 days
# 8238 -118.277923          1.0    3.000000 2009-01-20 2009-01-20        0 days
# 8274 -118.175270          1.0    5.000000 2015-12-18 2015-12-18        0 days
# 4    -118.308788          1.0    5.000000 2012-09-17 2012-09-17        0 days
# 8279 -118.284024          0.0         NaN        NaT        NaT           NaT
# 5777 -118.283807          0.0         NaN        NaT        NaT           NaT
# 3380 -118.308472          0.0         NaN        NaT        NaT           NaT
#
#      closed
# 860   False
# 9028  False
# 639   False
# 5225  False
# 436   False
# 6074  False
# 8945  False
# 2643  False
# 8654  False
# 6881  False
# 433   False
# 5594  False
# 583   False
# 7396  False
# 7215  False
# 3288  False
# 8292  False
# 8427  False
# 3669  False
# 308   False
# 5560  False
# 8995  False
# 8293  False
# 1081  False
# 4295  False
# 1634  False
# 1683  False
# 3242  False
# 6900  False
# 4990   True
# ...     ...
# 1116  False
# 5725  False
# 5662  False
# 7418  False
# 2172  False
# 2632  False
# 2675  False
# 5520   True
# 5519   True
# 84     True
# 8487  False
# 5845  False
# 2412  False
# 1117  False
# 6171   True
# 2173  False
# 2182  False
# 430    True
# 6234  False
# 6217  False
# 6166  False
# 9344  False
# 8171  False
# 2347  False
# 8238  False
# 8274   True
# 4     False
# 8279   True
# 5777   True
# 3380   True
#
# [3505 rows x 17 columns]

# %% [markdown]
# ## EDA

# %%
fig = plt.figure(figsize=(20,10))

sns.swarmplot(x='cat_1', y='num_reviews', hue='closed', data=ylp_lacnty_df)
plt.xlabel('Category', fontsize=20)
plt.xticks(rotation=45, ha='right', fontsize=14)
plt.yticks(fontsize=20)
plt.ylabel('Number of Reviews', fontsize=20)
plt.ylim(0, 5000)
plt.title('Number of Reviews by Category', fontsize=26)
plt.legend(bbox_to_anchor = (1, 1), loc = 2, handletextpad = 0.3, fontsize=14)
plt.show()

ylp_lacnty_df[['cat_1', 'name', 'num_reviews']].sort_values('num_reviews', ascending=False).head()
# Out:
#             cat_1                      name  num_reviews
# 860       italian             Bottega Louie      12873.0
# 9028       coffee  Urth Caffe - Downtown LA       4103.0
# 639       italian                    Bestia       3727.0
# 5225  newamerican         Masa of Echo Park       3106.0
# 436           bbq    Kang Ho-dong Baekjeong       2861.0

# %%
sns.distplot(ylp_lacnty_df['num_reviews'])
plt.xlim(0, 14000)
# Out:
# (0, 14000)
