# %% [markdown]
# # 1.01 County Data Cleanup

# %%
import os
os.chdir('../')

# %%
import pandas as pd
import numpy as np
import lib.county_data as ctd
import lib.name_categories as nc
import re
from lib.collapse_facil_dict import event_facil_addresses
from sklearn.externals import joblib

# %% [markdown]
# ## I. Load & Clean Data
#
# Download data from LA Public Health website (https://ehservices.publichealth.lacounty.gov/ezsearch) and read the data in using pandas

# %%
rest_df = pd.read_csv('data/LA_rest_inspects', delimiter = '\t', header = 0, index_col = False,
                             names = ['facility', 'last_inspect_date','inspect_score', 'descript',
                                      'address', 'city', 'zip', 'phone'])

# %%
rest_df.head()
# Out:
#                      facility last_inspect_date  inspect_score  \
# 0                103RD MARKET        01/18/2017           95.0
# 1           TACOS LA POTRANKA        01/18/2017           85.0
# 2                    FISHLAND        01/18/2017           97.0
# 3            PRODUCE FOR LESS        01/18/2017           91.0
# 4  TREE HOUSE THAI RESTAURANT        01/18/2017           92.0
#
#                                   descript                    address  \
# 0   FOOD MKT RETAIL (25-1,999 SF) LOW RISK            1922 E 103RD ST
# 1        RESTAURANT (0-30) SEATS HIGH RISK     1501 N LONG BEACH BLVD
# 2  FOOD MKT RETAIL (25-1,999 SF) HIGH RISK         510 W COMPTON BLVD
# 3    FOOD MKT RETAIL (2,000+ SF) HIGH RISK           5059 MELROSE AVE
# 4       RESTAURANT (31-60) SEATS HIGH RISK  10200 VENICE BLVD STE 207
#
#           city         zip         phone
# 0  LOS ANGELES       90002  323-563-6245
# 1      COMPTON  90221-1608  323-928-1229
# 2      COMPTON       90220  310-669-3050
# 3  LOS ANGELES  90038-4115  323-466-2966
# 4  CULVER CITY       90232           NaN

# %% [markdown]
# ## II. Clean the Data
#
# Note, all functions are stored in a separate `county_data.py` file.
#
# - strip columns of any spaces when possible
# - filter out any food facilities that do not serve customers (i.e. retail)
# - extract necessary data and move into separate columns (seat range, risk, zip codes, phone numbers)
# - remove key words that may not help the Yelp search

# %%
ctd.strip_col_contents(rest_df)
# Out:
# SUCCESS     : facility column stripped
# SUCCESS     : last_inspect_date column stripped
# UNSUCCESSFUL: inspect_score column not stripped due to format
# SUCCESS     : descript column stripped
# SUCCESS     : address column stripped
# SUCCESS     : city column stripped
# SUCCESS     : zip column stripped
# UNSUCCESSFUL: phone column not stripped due to format

# %%
rest_df = ctd.filter_dataframe('restaurant', 'descript', rest_df)

# %%
rest_df[rest_df['city'] == 'LOS ANGELES'].sort_values('facility')
# Out:
#                                facility last_inspect_date  inspect_score  \
# 22794           # 245 FRIES FRIES FRIES        09/21/2016           96.0
# 28835            # 431 LOGE TERRACE BAR        08/09/2016           99.0
# 22608               # 953 TOP DECK DOGS        09/21/2016           98.0
# 27476                           #1 CAFE        08/18/2016           90.0
# 28626              #1 CHINESE FAST FOOD        08/10/2016           92.0
# 34914                          #1 DONUT        05/17/2016           98.0
# 30533                         #1 DONUTS        07/26/2016           91.0
# 29068         #102 ALL INCLUSIVE (AYCE)        08/08/2016           98.0
# 29073       #103 DODGER DOG TRADITIONAL        08/08/2016           99.0
# 29119         #104 ALL INCLUSIVE (AYCE)        08/08/2016           99.0
# 29058       #105 DODGER DOG TRADITIONAL        08/08/2016           99.0
# 18981                       #2 MOON BBQ        10/12/2016           92.0
# 29092               #204 CAMPY'S CORNER        08/08/2016           99.0
# 29159   #205 MARKET PLACE HEALTHY PLATE        08/08/2016           98.0
# 22589       #208 BROOKLYN DODGERS PIZZA        09/21/2016           99.0
# 29125      #209  DODGER DOG TRADITIONAL        08/08/2016           93.0
# 29138               #210 TENDER'S, ETC.        08/08/2016           98.0
# 22504           #222 ELYSIAN PARK GRILL        09/21/2016           99.0
# 29144      #223 DODGER DOGS TRADITIONAL        08/08/2016           99.0
# 29166      #240  DODGER DOG TRADITIONAL        08/08/2016           95.0
# 29082      #241 DODGER DOGS TRADITIONAL        08/08/2016           99.0
# 29080       #246 DODGER DOG TRADITIONAL        08/08/2016          100.0
# 22726              #247 DODGERTOWN DELI        09/21/2016           98.0
# 28796       #248 DODGER DOG TRADITIONAL        08/09/2016           97.0
# 22717               #251 THINK BLUE BBQ        09/21/2016          100.0
# 22555    #252 TOMMY LASORDA'S TRATTORIA        09/21/2016           99.0
# 32342                #400 FROZEN YOGURT        07/07/2016          100.0
# 26952       #418 DODGER DOG TRADITIONAL        08/23/2016           99.0
# 32355                     #419 HITE BAR        07/07/2016           99.0
# 27049       #420 BROOKLIN DODGERS PIZZA        08/23/2016           98.0
# ...                                 ...               ...            ...
# 33722                     ZACATECAS BAR        06/10/2016           96.0
# 34973                         ZAHN CAFE        05/16/2016           99.0
# 50453               ZAMARANO RESTAURANT        08/08/2013           93.0
# 31386            ZAMORA BROS RESTAURANT        07/19/2016           96.0
# 49848                   ZAMORA BROTHERS        10/28/2013           93.0
# 22898                        ZAN RESPUB        09/20/2016           92.0
# 14141                    ZANKOU CHICKEN        11/03/2016           99.0
# 19384                    ZANKOU CHICKEN        10/11/2016           96.0
# 24511                    ZANKOU-CHICKEN        09/12/2016           95.0
# 46251                          ZAPOTECA        10/16/2014           90.0
# 7682                      ZEIDLERS CAFE        12/07/2016           99.0
# 49285          ZELMA'S SOUL FOOD & MORE        01/15/2014           91.0
# 4889                ZEN BAKERY (RETAIL)        12/19/2016           97.0
# 2865                     ZEN MEI BISTRO        01/03/2017           83.0
# 7027                ZENCU SUSHI & GRILL        12/09/2016           90.0
# 902             ZERMENOS RESTAURANT INC        01/11/2017           91.0
# 41006               ZEUSS BAR AND GRILL        10/15/2015           97.0
# 28099                     ZIA VALENTINA        08/15/2016           94.0
# 293               ZINGO TACOS AL CARBON        01/13/2017           93.0
# 10954         ZION MARKET DELI & ISLAND        11/21/2016           94.0
# 47079                  ZIP FUSION SUSHI        08/14/2014           90.0
# 35568               ZIP SUSHI & IZAKAYA        05/04/2016           90.0
# 31022                                ZO        07/21/2016           95.0
# 5194                    ZOO GRILL KIOSK        12/15/2016           97.0
# 15716            ZOO PRODUCTION KITCHEN        10/27/2016           95.0
# 4846                       ZUMA KITCHEN        12/19/2016           90.0
# 41832  ZUMBA & AEROBICS CLOTHING ASHLEY        09/08/2015           15.0
# 35674                        ZWEET CAFE        05/03/2016           95.0
# 25362                ZWONNY KITCHEN INC        09/06/2016           92.0
# 23217                           ZZAMONG        09/19/2016           93.0
#
#                                       descript  \
# 22794        RESTAURANT (0-30) SEATS HIGH RISK
# 28835    RESTAURANT (0-30) SEATS MODERATE RISK
# 22608      RESTAURANT (151 + ) SEATS HIGH RISK
# 27476        RESTAURANT (0-30) SEATS HIGH RISK
# 28626        RESTAURANT (0-30) SEATS HIGH RISK
# 34914    RESTAURANT (0-30) SEATS MODERATE RISK
# 30533    RESTAURANT (0-30) SEATS MODERATE RISK
# 29068    RESTAURANT (0-30) SEATS MODERATE RISK
# 29073    RESTAURANT (0-30) SEATS MODERATE RISK
# 29119    RESTAURANT (0-30) SEATS MODERATE RISK
# 29058    RESTAURANT (0-30) SEATS MODERATE RISK
# 18981      RESTAURANT (61-150) SEATS HIGH RISK
# 29092    RESTAURANT (0-30) SEATS MODERATE RISK
# 29159         RESTAURANT (0-30) SEATS LOW RISK
# 22589        RESTAURANT (0-30) SEATS HIGH RISK
# 29125    RESTAURANT (0-30) SEATS MODERATE RISK
# 29138    RESTAURANT (0-30) SEATS MODERATE RISK
# 22504        RESTAURANT (0-30) SEATS HIGH RISK
# 29144    RESTAURANT (0-30) SEATS MODERATE RISK
# 29166    RESTAURANT (0-30) SEATS MODERATE RISK
# 29082    RESTAURANT (0-30) SEATS MODERATE RISK
# 29080    RESTAURANT (0-30) SEATS MODERATE RISK
# 22726        RESTAURANT (0-30) SEATS HIGH RISK
# 28796    RESTAURANT (0-30) SEATS MODERATE RISK
# 22717        RESTAURANT (0-30) SEATS HIGH RISK
# 22555        RESTAURANT (0-30) SEATS HIGH RISK
# 32342    RESTAURANT (0-30) SEATS MODERATE RISK
# 26952    RESTAURANT (0-30) SEATS MODERATE RISK
# 32355    RESTAURANT (0-30) SEATS MODERATE RISK
# 27049    RESTAURANT (0-30) SEATS MODERATE RISK
# ...                                        ...
# 33722         RESTAURANT (0-30) SEATS LOW RISK
# 34973  RESTAURANT (61-150) SEATS MODERATE RISK
# 50453        RESTAURANT (0-30) SEATS HIGH RISK
# 31386        RESTAURANT (0-30) SEATS HIGH RISK
# 49848        RESTAURANT (0-30) SEATS HIGH RISK
# 22898      RESTAURANT (61-150) SEATS HIGH RISK
# 14141       RESTAURANT (31-60) SEATS HIGH RISK
# 19384      RESTAURANT (61-150) SEATS HIGH RISK
# 24511       RESTAURANT (31-60) SEATS HIGH RISK
# 46251        RESTAURANT (0-30) SEATS HIGH RISK
# 7682       RESTAURANT (61-150) SEATS HIGH RISK
# 49285    RESTAURANT (0-30) SEATS MODERATE RISK
# 4889     RESTAURANT (0-30) SEATS MODERATE RISK
# 2865        RESTAURANT (31-60) SEATS HIGH RISK
# 7027       RESTAURANT (61-150) SEATS HIGH RISK
# 902          RESTAURANT (0-30) SEATS HIGH RISK
# 41006  RESTAURANT (61-150) SEATS MODERATE RISK
# 28099    RESTAURANT (0-30) SEATS MODERATE RISK
# 293          RESTAURANT (0-30) SEATS HIGH RISK
# 10954        RESTAURANT (0-30) SEATS HIGH RISK
# 47079      RESTAURANT (61-150) SEATS HIGH RISK
# 35568      RESTAURANT (61-150) SEATS HIGH RISK
# 31022        RESTAURANT (0-30) SEATS HIGH RISK
# 5194          RESTAURANT (0-30) SEATS LOW RISK
# 15716        RESTAURANT (0-30) SEATS HIGH RISK
# 4846       RESTAURANT (61-150) SEATS HIGH RISK
# 41832    RESTAURANT (0-30) SEATS MODERATE RISK
# 35674    RESTAURANT (0-30) SEATS MODERATE RISK
# 25362       RESTAURANT (31-60) SEATS HIGH RISK
# 23217       RESTAURANT (31-60) SEATS HIGH RISK
#
#                                 address         city         zip         phone
# 22794               1000 VIN SCULLY AVE  LOS ANGELES       90012           NaN
# 28835               1000 VIN SCULLY AVE  LOS ANGELES       90012           NaN
# 22608               1000 VIN SCULLY AVE  LOS ANGELES       90012           NaN
# 27476       2080 CENTURY PARK E STE 108  LOS ANGELES       90067           NaN
# 28626                8606 S VERMONT AVE  LOS ANGELES       90044  213-235-8779
# 34914                8509 S FIGUEROA ST  LOS ANGELES       90003           NaN
# 30533          8509 S FIGUEROA ST # 106  LOS ANGELES       90003  626-695-7898
# 29068               1000 VIN SCULLY AVE  LOS ANGELES       90012           NaN
# 29073               1000 VIN SCULLY AVE  LOS ANGELES       90012           NaN
# 29119               1000 VIN SCULLY AVE  LOS ANGELES       90012           NaN
# 29058               1000 VIN SCULLY AVE  LOS ANGELES       90012           NaN
# 18981                 478 N WESTERN AVE  LOS ANGELES       90004  323-465-6707
# 29092               1000 VIN SCULLY AVE  LOS ANGELES       90012           NaN
# 29159               1000 VIN SCULLY AVE  LOS ANGELES       90012           NaN
# 22589               1000 VIN SCULLY AVE  LOS ANGELES       90012           NaN
# 29125               1000 VIN SCULLY AVE  LOS ANGELES       90012           NaN
# 29138               1000 VIN SCULLY AVE  LOS ANGELES       90012           NaN
# 22504               1000 VIN SCULLY AVE  LOS ANGELES       90012           NaN
# 29144               1000 VIN SCULLY AVE  LOS ANGELES       90012           NaN
# 29166               1000 VIN SCULLY AVE  LOS ANGELES       90012           NaN
# 29082               1000 VIN SCULLY AVE  LOS ANGELES       90012           NaN
# 29080               1000 VIN SCULLY AVE  LOS ANGELES       90012           NaN
# 22726               1000 VIN SCULLY AVE  LOS ANGELES       90012           NaN
# 28796               1000 VIN SCULLY AVE  LOS ANGELES       90012           NaN
# 22717               1000 VIN SCULLY AVE  LOS ANGELES       90012           NaN
# 22555               1000 VIN SCULLY AVE  LOS ANGELES       90012           NaN
# 32342               1000 VIN SCULLY AVE  LOS ANGELES       90012           NaN
# 26952               1000 VIN SCULLY AVE  LOS ANGELES       90012           NaN
# 32355               1000 VIN SCULLY AVE  LOS ANGELES       90012           NaN
# 27049               1000 VIN SCULLY AVE  LOS ANGELES       90012           NaN
# ...                                 ...          ...         ...           ...
# 33722                   6300 S BROADWAY  LOS ANGELES       90003           NaN
# 34973             832 JAMES M WOOD BLVD  LOS ANGELES  90015-1352  213-438-1617
# 50453                  5400 AVALON BLVD  LOS ANGELES       90011  562-500-6895
# 31386                  1559 W PICO BLVD  LOS ANGELES       90015  213-385-5553
# 49848         4771 E CESAR E CHAVEZ AVE  LOS ANGELES       90022           NaN
# 22898          3377 WILSHIRE BLVD # 200  LOS ANGELES       90010  213-388-2337
# 14141                7851 W SUNSET BLVD  LOS ANGELES       90046  323-882-6365
# 19384                5065 W SUNSET BLVD  LOS ANGELES       90027           NaN
# 24511             1716 S SEPULVEDA BLVD  LOS ANGELES       90025           NaN
# 46251                  4220 W PICO BLVD  LOS ANGELES       90019           NaN
# 7682              2701 N SEPULVEDA BLVD  LOS ANGELES       90049           NaN
# 49285               1561 W FLORENCE AVE  LOS ANGELES       90047  323-751-4688
# 4889                  10988 W PICO BLVD  LOS ANGELES  90064-2115  310-475-6727
# 2865                        800 YALE ST  LOS ANGELES       90012  213-626-7113
# 7027               319 E 2ND ST STE 206  LOS ANGELES       90012           NaN
# 902    6115 SANTA MONICA BLVD UNIT UNIT  LOS ANGELES       90038           NaN
# 41006                2700 N VERMONT AVE  LOS ANGELES       90027           NaN
# 28099                6333 W 3RD ST #530  LOS ANGELES       90036  310-728-0100
# 293                    5234 VALLEY BLVD  LOS ANGELES  90032-3946  323-201-1994
# 10954             3500 W 6TH ST STE 100  LOS ANGELES       90020  213-351-9900
# 47079                      744 E 3RD ST  LOS ANGELES       90013           NaN
# 35568                      744 E 3RD ST  LOS ANGELES       90013  213-680-3770
# 31022               334 S MAIN ST #1106  LOS ANGELES       90013  213-935-8409
# 5194                        5333 ZOO DR  LOS ANGELES       90027  323-644-6039
# 15716                       5333 ZOO DR  LOS ANGELES       90027  323-644-6039
# 4846                 1942 WESTWOOD BLVD  LOS ANGELES       90025  310-446-0055
# 41832                4157 S CENTRAL AVE  LOS ANGELES       90011  323-362-0192
# 35674              4682 EAGLE ROCK BLVD  LOS ANGELES       90041  323-254-0797
# 25362                 857 S WESTERN AVE  LOS ANGELES       90005  213-393-1969
# 23217                     4255 W 3RD ST  LOS ANGELES       90020  213-739-2747
#
# [10273 rows x 8 columns]

# %%
rest_df['address'] = rest_df['address'].apply(lambda x: re.sub(' STE$','',x))
rest_df['address'] = rest_df['address'].apply(lambda x: re.sub(' STE .+','',x))
rest_df['address'] = rest_df['address'].apply(lambda x: re.sub(' STE#.+','',x))
rest_df['address'] = rest_df['address'].apply(lambda x: re.sub(' # .+','',x))
rest_df['address'] = rest_df['address'].apply(lambda x: re.sub(' #.+','',x))
rest_df['address'] = rest_df['address'].apply(lambda x: re.sub('#\d+','',x))
rest_df['address'] = rest_df['address'].apply(lambda x: re.sub('# \d+','',x))
rest_df['address'] = rest_df['address'].apply(lambda x: re.sub('#$','',x))

# %%
rest_df['max_seats'] = rest_df['descript'].str.extract('RESTAURANT \((.+)\)', expand = True)

# %%
rest_df['max_seats'] = rest_df['max_seats'].apply(ctd.max_seating)

# %%
rest_df['phone'] = rest_df['phone'].str.replace('-','')

# %%
rest_df['risk_level'] = rest_df['descript'].str.extract('\) SEATS (.+) RISK', expand = True)

# %%
rest_df['risk_level'] = rest_df['risk_level'].apply(ctd.risk_lev)

# %%
rest_df['zip_cd'] = rest_df['zip'].str.extract('(\d{5})', expand = True)

# %%
rest_df['facility'] = rest_df['facility'].str.replace(',', '')
rest_df['facility'] = rest_df['facility'].str.replace("'", '')
rest_df['facility'] = rest_df['facility'].str.replace(' #\d+', '')
rest_df['facility'] = rest_df['facility'].str.replace(' # \d+', '')
rest_df['facility'] = rest_df['facility'].str.replace(' INC', '')

# %%
rest_df.drop('descript', axis = 1, inplace = True)
rest_df.drop('zip', axis = 1, inplace = True)
rest_df.dropna(axis=0, subset=['zip_cd'], inplace=True)

# %%
rest_df['zip_cd'] = rest_df['zip_cd'].astype('str')

# %%
rest_df['phone'] = rest_df['phone'].apply(lambda x: '+1' + str(x))

# %%
rest_df = rest_df.groupby(['facility', 'address', 'city', 'zip_cd'], 
                            as_index = False).agg({'max_seats': 'max',
                                                   'risk_level': 'max',
                                                   'last_inspect_date': 'max',
                                                   'inspect_score': 'mean',
                                                   'phone': 'min'})
rest_df.head()
# Out:
#                   facility               address         city zip_cd  \
# 0  # 245 FRIES FRIES FRIES   1000 VIN SCULLY AVE  LOS ANGELES  90012
# 1   # 431 LOGE TERRACE BAR   1000 VIN SCULLY AVE  LOS ANGELES  90012
# 2      # 953 TOP DECK DOGS   1000 VIN SCULLY AVE  LOS ANGELES  90012
# 3                #1 BUFFET  14418 HAWTHORNE BLVD     LAWNDALE  90260
# 4                  #1 CAFE   2080 CENTURY PARK E  LOS ANGELES  90067
#
#    max_seats         phone  risk_level last_inspect_date  inspect_score
# 0         30         +1nan           3        09/21/2016           96.0
# 1         30         +1nan           2        08/09/2016           99.0
# 2        151         +1nan           3        09/21/2016           98.0
# 3        151  +13106444007           3        11/29/2016           90.0
# 4         30         +1nan           3        08/18/2016           90.0

# %%
rest_cities = rest_df.groupby('city', as_index = False).agg({'facility': 'count'})

# %%
rest_cities = rest_cities.sort_values('facility', ascending = False)

# %% [markdown]
# ### A. Narrow the Scope
#
# - focus on restaurants in neighbrohoods with over 100 restaurants, so we can take saturation into account later
# - note that Los Angeles is quite broad, and contains 28% of the entire data set

# %%
rest_cities.head()
# Out:
#              city  facility
# 81    LOS ANGELES      9945
# 152      TORRANCE       810
# 132  SANTA MONICA       782
# 46       GLENDALE       719
# 20        BURBANK       584

# %%
rest_cities['filter'] = rest_cities['facility'].apply(lambda x: 1 if x > 100 else 0)

# %%
rest_cities = ctd.filter_and_drop_column(rest_cities)

# %%
rest_scope = rest_cities['city'].values

# %%
rest_df['filter'] = rest_df['city'].apply(lambda x: 1 if x in rest_scope else 0)

# %%
rest_df = ctd.filter_and_drop_column(rest_df)

# %% [markdown]
# ### B. Consolidate the Data
#
# There's a lot of potentially duplicative data. We need to differentiate between a couple of things:
# - multiple restaurant offerings at one address
# - restaurant turnover at the same address
# - the same restaurant receiving yearly inspections under different names
#
# To better understand and solve this problem, I'm going to create a dictionary of addresses, with the values as a list of different restaurant names.
#
# In addition, we have another check coming on the Yelp API, so we don't have to spend too much time on this.

# %%
rest_facil_dict = rest_df.groupby('address').groups

# %%
for key, value in rest_facil_dict.items():
    index_list = []
    for index_num in value:
        index_num = rest_df.ix[index_num]['facility']
        index_list.append(index_num)
    rest_facil_dict[key] = index_list

# %%
def num_rest(x):
    if x in rest_facil_dict:
        return len(rest_facil_dict[x])

rest_df['num_at_address'] = rest_df['address'].apply(num_rest)

# %%
rest_df['facility'] = rest_df.apply(lambda col: ctd.rename_facilities(col['address'],
                                                                      col['facility']), axis = 1)

# %%
rest_group_df = rest_df.groupby(['facility', 'address', 'city', 'zip_cd', 'num_at_address'], 
                                as_index = False).agg({'max_seats': 'max',
                                                       'risk_level': 'max',
                                                       'last_inspect_date': 'max',
                                                       'inspect_score': 'mean',
                                                       'phone': 'min'})

# %%
rest_group_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31996 entries, 0 to 31995
# Data columns (total 10 columns):
# facility             31996 non-null object
# address              31996 non-null object
# city                 31996 non-null object
# zip_cd               31996 non-null object
# num_at_address       31996 non-null int64
# max_seats            31996 non-null int64
# phone                31996 non-null object
# risk_level           31996 non-null int64
# last_inspect_date    31996 non-null object
# inspect_score        31996 non-null float64
# dtypes: float64(1), int64(3), object(6)
# memory usage: 2.7+ MB

# %%
rest_group_df['cat'] = rest_group_df['facility'].apply(nc.define_cat)

# %%
rest_group_df = rest_group_df[rest_group_df['cat'].isnull()]

# %%
rest_group_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30850 entries, 0 to 31995
# Data columns (total 11 columns):
# facility             30850 non-null object
# address              30850 non-null object
# city                 30850 non-null object
# zip_cd               30850 non-null object
# num_at_address       30850 non-null int64
# max_seats            30850 non-null int64
# phone                30850 non-null object
# risk_level           30850 non-null int64
# last_inspect_date    30850 non-null object
# inspect_score        30850 non-null float64
# cat                  0 non-null object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 2.8+ MB

# %%
la_rest_group_df = rest_group_df[rest_group_df['city'] == 'LOS ANGELES']

# %%
pd.to_pickle(la_rest_group_df, 'data/la_rest_group_df.pkl')
